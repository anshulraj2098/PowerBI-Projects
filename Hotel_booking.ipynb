# %% [markdown]
# <a href="https://colab.research.google.com/github/anshulraj2098/PowerBI-Projects/blob/main/Hotel_booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load up the dataset, using the file path & separating it using a delimited. Then accessing the top 5 rows.

# %%
df = pd.read_csv('/content/Python Practice/hotel-booking-data.txt', delimiter='\t')
df.head()
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %% [markdown]
# this function gives a brief idea about the data. Useful in calculation.

# %%
df.describe()
# Out:
#        Room number
# count   153.000000
# mean   3079.326797
# std    1718.791186
# min    1001.000000
# 25%    2001.000000
# 50%    3008.000000
# 75%    4010.000000
# max    7002.000000

# %% [markdown]
# This function counts a certain selected columns.

# %%
df['Company'].value_counts()
# Out:
# Company
# Leexo           3
# Quinu           3
# Fivechat        3
# Twitterlist     2
# Jayo            2
#                ..
# Twitterwire     1
# Skiba           1
# Tagpad          1
# Innojam         1
# Twitterworks    1
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# This function removes the empty tables

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %% [markdown]
# Adding a certian number columns (for doing calculations).

# %%
df['Room No*2'] = df['Room number'] * 2

# %%
df
# Out:
#            Date       Company        Person Name  Room number  Room No*2
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0     8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0     4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0     8024.0
# 3        Hotels           NaN                NaN          NaN        NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0     2012.0
# ..          ...           ...                ...          ...        ...
# 190   Cleartrip           NaN                NaN          NaN        NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0     8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0    10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0     2020.0
# 194      Hotels           NaN                NaN          NaN        NaN
#
# [195 rows x 5 columns]

# %% [markdown]
# Adding a new dataframe, just like adding a new worksheet which won't change or hamper the original dataset. Accesing the new dataframe.

# %%
new_df = df.dropna()

# %%
new_df.head()
# Out:
#          Date Company          Person Name  Room number  Room No*2
# 0  1-Jan-2022  Avamba    Anatole Ridehalgh       4008.0     8016.0
# 1  1-Jan-2022    Fatz      Aldrich McKevin       2002.0     4004.0
# 2  1-Jan-2022   Leexo      Stanley Hadrill       4012.0     8024.0
# 4  1-Jan-2022  Rhyzio         Lyndell Tice       1006.0     2012.0
# 5  1-Jan-2022   Eadel  Broderic Handscombe       3015.0     6030.0

# %% [markdown]
# Checking if the old dataframe still exist

# %%
df
# Out:
#            Date       Company        Person Name  Room number  Room No*2
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0     8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0     4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0     8024.0
# 3        Hotels           NaN                NaN          NaN        NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0     2012.0
# ..          ...           ...                ...          ...        ...
# 190   Cleartrip           NaN                NaN          NaN        NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0     8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0    10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0     2020.0
# 194      Hotels           NaN                NaN          NaN        NaN
#
# [195 rows x 5 columns]

# %% [markdown]
# Checking for True and Flase value.

# %%
df['Room number'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193    False
# 194     True
# Name: Room number, Length: 195, dtype: bool

# %% [markdown]
# Created a condition called "mask" as per the above checking(true or false) -> creating a new column "Text value" and

# %%
mask = df['Room number'].isna()

df['Text Value'] = np.where(mask, df['Date'], np.nan)

df
# Out:
#            Date       Company        Person Name  Room number  Room No*2  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0     8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0     4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0     8024.0
# 3        Hotels           NaN                NaN          NaN        NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0     2012.0
# ..          ...           ...                ...          ...        ...
# 190   Cleartrip           NaN                NaN          NaN        NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0     8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0    10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0     2020.0
# 194      Hotels           NaN                NaN          NaN        NaN
#
#     Text Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Hotels
# ...

# %% [markdown]
# In Chandoo's video he was using an old methoed which Python suggested that it has been deprecated and no longer being used, also suggested the alternate to what to use. Hence, with the help of gemini replaced Chandoo's "inplace" & "Method" code(df['Text Value'].fillna(method='bfill', inplace=True). It is replaced with the below code.

# %%
df['Text Value'] = df['Text Value'].bfill()

# %%
df
# Out:
#            Date       Company        Person Name  Room number  Room No*2  \
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0     8016.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0     4004.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0     8024.0
# 3        Hotels           NaN                NaN          NaN        NaN
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0     2012.0
# ..          ...           ...                ...          ...        ...
# 190   Cleartrip           NaN                NaN          NaN        NaN
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0     8016.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0    10004.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0     2020.0
# 194      Hotels           NaN                NaN          NaN        NaN
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# 3       Hotels
# ...

# %% [markdown]
# To remove the NaN values from the df

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            Date       Company          Person Name  Room number  Room No*2  \
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0     8016.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0     4004.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0     8024.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0     2012.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0     6030.0
# ..          ...           ...                  ...          ...        ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0     2030.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0    14004.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0     8016.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0    10004.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0     2020.0
#
#     Text Value
# 0       Hotels
# 1       Hotels
# 2       Hotels
# ...

# %%
df.value_counts('Text Value')
# Out:
# Text Value
# Expedia             48
# Hotels              39
# Booking             24
# Travel Agent 007    12
# Cleartrip           11
# Name: count, dtype: int64

# %%
df3 = df.value_counts('Text Value')
df3.plot()
# Out:
# <Axes: xlabel='Text Value'>
